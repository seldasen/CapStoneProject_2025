# %% [markdown]
# # **Basic Statistical Concepts and Data Analysis**

# %% [markdown]
# Basic Statistical Concepts and Data Analysis
# 1.1 Principles of Statistics, Probability, and Data Analysis
# Statistics is the branch of science used to collect, organize, analyze, and interpret data. The fundamental statistical concepts in the data analysis process are as follows:
#
# 1.1.1 Mean
# The mean is obtained by dividing the sum of all values in a dataset by the number of elements.
#
# Here, each data point is represented, and is the total number of elements in the dataset.
#
# 1.1.2 Median
# The median is the middle value in an ordered dataset. If the number of elements is odd, it is the exact middle value; if even, it is the average of the two middle values.
#
# 1.1.3 Mode
# The mode is the most frequently occurring value in a dataset. A dataset may have multiple modes or no mode at all.
#
# 1.1.4 Standard Deviation
# Standard deviation indicates how much the data deviates from the mean. A small standard deviation means the data is close to the mean, while a large standard deviation signifies a wide distribution.
#
# Here, represents the mean of the dataset.
#
# 1.1.5 Variance
# Variance is the square of the standard deviation and shows the spread of the data distribution.
#
# 1.1.6 Probability Distributions
# Probability distributions represent the likelihood of an event occurring. One of the most common distributions is the normal distribution. The normal distribution is bell-shaped and represents the distribution of many natural phenomena.
#
# Here, represents the mean, and represents the standard deviation.
#
# 1.1.7 Hypothesis Testing
# Hypothesis testing is used to determine whether there is a statistically significant difference. One of the most commonly used tests is the t-test, which measures whether the difference in means between two groups is significant.It's appropriate when you want to test if there is a statistically significant difference between two independent or related groups (e.g., comparing the test scores of two classes).
#
# The hypothesis testing process follows these steps:
#
# Null Hypothesis (H₀): The assumption that there is no effect or no difference between groups.
#
# Alternative Hypothesis (H₁): The assumption that there is a significant effect or difference between groups.
#
# P-value: The probability of observing the data if the null hypothesis is true. If the p-value is less than the significance level (usually 0.05), the null hypothesis is rejected.
#
#
# ANOVA (Analysis of Variance): Used to compare the means of three or more groups. It's suitable when you're testing if at least one of the group means differs significantly from others (e.g., comparing the test scores of three different classes).
#
# Correlation Analysis: Used to measure the strength and direction of the relationship between two continuous variables (e.g., the relationship between hours studied and exam scores). A correlation coefficient (e.g., Pearson’s r) indicates the strength and direction of the association.

# %% [markdown]
# Statistical Analysis with Python
# Now, we will apply the concepts above by writing code in Jupyter Notebook.
#
# Calculating Mean, Median, Standard Deviation, and Variance

# %%
import pandas as pd
import numpy as np

#  Load the data
data = pd.read_csv(r"C:\Users\balla\OneDrive\Documents\CapStoneProject_2025\combined_20202024_cleaned.csv")

# Select numerical columns
numeric_columns = data.select_dtypes(include=['float64', 'int64']).columns

# Compute basic statistics
mean_values = data[numeric_columns].mean()
median_values = data[numeric_columns].median()
std_values = data[numeric_columns].std()
var_values = data[numeric_columns].var()

print("📌 Mean Values:\n", mean_values)
print("\n📌 Median Values:\n", median_values)
print("\n📌 Standard Deviation Values:\n", std_values)
print("\n📌 Variance Values:\n", var_values)
# Out:
# 📌 Mean Values:
#  Happiness Rank                    73.401099
# Happiness score                    5.524740
# Upperwhisker                       5.640658
# Lowerwhisker                       5.408864
# Economy (GDP per Capita)\t         1.200348
# Social support                     1.026796
# Healthy life expectancy            0.541228
# Freedom to make life choices       0.526359
# Generosity                         0.162572
# Perceptions of corruption          0.143833
# Year                            2021.956044
# dtype: float64
#
# 📌 Median Values:
#  Happiness Rank                    73.0000
# Happiness score                    5.5830
# Upperwhisker                       5.6895
# Lowerwhisker                       5.4820
# Economy (GDP per Capita)\t         1.2395
# Social support                     1.0670
# Healthy life expectancy            0.5550
# Freedom to make life choices       0.5465
# Generosity                         0.1490
# ...

# %% [markdown]
# Hypothesis Testing (T-Test)
# Now, let's perform a t-test to determine whether there is a statistically significant difference between the means of two data groups.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,5))
sns.histplot(data["Happiness score"], kde=True, bins=30)
plt.xlabel("Happiness score")
plt.ylabel("Frequency")
plt.title("Distribution of Happiness Scores")
plt.show()

# %% [markdown]
# Normal Distribution Graph
# Let's plot a histogram to visualize the normal distribution of happiness scores.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import numpy as np

# Veriyi alma
happiness_scores = data["Happiness score"].dropna()

# Histogram çizimi
plt.figure(figsize=(10, 5))
sns.histplot(happiness_scores, kde=True, bins=30, color="skyblue", stat="density")

# Normal dağılım eğrisini ekleme
mean = happiness_scores.mean()
std = happiness_scores.std()
x = np.linspace(happiness_scores.min(), happiness_scores.max(), 100)
y = stats.norm.pdf(x, mean, std)
plt.plot(x, y, color="red", label="Normal Distribution")

# Grafik detayları
plt.xlabel("Happiness Score")
plt.ylabel("Density")
plt.title("Normal Distribution of Happiness Scores")
plt.legend()
plt.show()

# %% [markdown]
# 🎛 3. Dashboard Entegrasyonu
# Şimdi, bu istatistikleri bir dashboard’a nasıl ekleyebileceğimizi düşünelim.
#
# Ortalama ve varyans gibi değerleri gösteren bir tablo ekleyebiliriz.
# Normal dağılım histogramını bir görselleştirme olarak ekleyebiliriz.
# Hipotez testi sonuçlarını bir metin kutusunda gösterebiliriz.

# %%
import pandas as pd

df = pd.read_csv('C:\\Users\\balla\\OneDrive\\Documents\\CapStoneProject_2025\\combined_20202024_cleaned.csv')
print(df)

# Mean Happiness Score
mean_happiness = df['Happiness score'].mean()
print(f'Mean Happiness Score: {mean_happiness}')
# Out:
#          Country name  Happiness Rank  Happiness score  Upperwhisker  \
# 0             Finland               1            7.810         7.870
# 1             Denmark               2            7.650         7.710
# 2         Switzerland               3            7.560         7.630
# 3             Iceland               4            7.500         7.620
# 4              Norway               5            7.490         7.560
# ..                ...             ...              ...           ...
# 723  Congo (Kinshasa)             139            3.295         3.462
# 724      Sierra Leone             140            3.245         3.366
# 725           Lesotho             141            3.186         3.469
# 726           Lebanon             142            2.707         2.797
# 727       Afghanistan             143            1.721         1.775
#
#      Lowerwhisker  Economy (GDP per Capita)\t  Social support  \
# 0           7.750                       1.290           1.500
# ...

# %% [markdown]
# 1.1.2 Median
# Definition: The median is the middle value in a dataset when the numbers are arranged in order. If there is an even number of data points, the median is the average of the two middle numbers.
#
# Formula: There isn't a single formula for the median, but the process involves sorting the data and finding the middle value.
#
# calculate the median happiness score:

# %%
median_happiness = df['Happiness score'].median()
print(f'Median Happiness Score: {median_happiness}')
# Out:
# Median Happiness Score: 5.583

# %% [markdown]
# 1.1.3 Standard Deviation
#
# Definition: The standard deviation measures the amount of variation or dispersion of a dataset. A low standard deviation means that the data points are close to the mean, while a high standard deviation means that the data points are spread out.
#
#  calculate the standard deviation of happiness scores:

# %% [markdown]
# ## Objectives
#
# * Write your notebook objective here, for example, "Fetch data from Kaggle and save as raw data", or "engineer features for modelling"
#
# ## Inputs
#
# * Write down which data or information you need to run the notebook
#
# ## Outputs
#
# * Write here which files, code or artefacts you generate by the end of the notebook
#
# ## Additional Comments
#
# * If you have any additional comments that don't fit in the previous bullets, please state them here.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir

# %% [markdown]
# # Section 1

# %% [markdown]
# Section 1 content

# %% [markdown]
# ---

# %% [markdown]
# # Section 2

# %% [markdown]
# Section 2 content

# %% [markdown]
# ---

# %% [markdown]
# NOTE

# %% [markdown]
# * You may add as many sections as you want, as long as it supports your project workflow.
# * All notebook's cells should be run top-down (you can't create a dynamic wherein a given point you need to go back to a previous cell to execute some task, like go back to a previous cell and refresh a variable content)

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# * In cases where you don't need to push files to Repo, you may replace this section with "Conclusions and Next Steps" and state your conclusions and next steps.

# %%
import os
try:
  # create your folder here
  # os.makedirs(name='')
except Exception as e:
  print(e)
