# %% [markdown]
# # **WORLD HAPPINESS REPORT**

# %%
import pandas as pd

# Load Dataset
df = pd.read_csv(r"C:\Users\balla\OneDrive\Documents\CapStoneProject_2025\Data\Combined_Cleaned.csv")
# Show first 5 rows
print(df.head())

# general information about the dataset
print(df.info())

# summary statistics
print(df.describe())
# Out:
#   Country_name  Happiness_Rank  Happiness_score  Upperwhisker  Lowerwhisker  \
# 0      Finland               1             7.81          7.87          7.75
# 1      Denmark               2             7.65          7.71          7.58
# 2  Switzerland               3             7.56          7.63          7.49
# 3      Iceland               4             7.50          7.62          7.39
# 4       Norway               5             7.49          7.56          7.42
#
#    Economy_(GDP_per_Capita)\t  Social_support  Healthy_life_expectancy  \
# 0                        1.29            1.50                     0.96
# 1                        1.33            1.50                     0.98
# 2                        1.39            1.47                     1.04
# 3                        1.33            1.55                     1.00
# 4                        1.42            1.50                     1.01
#
#    Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption  Year
# 0                          0.66        0.16                       0.48  2020
# 1                          0.67        0.24                       0.50  2020
# 2                          0.63        0.27                       0.41  2020
# 3                          0.66        0.36                       0.14  2020
# 4                          0.67        0.29                       0.43  2020
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 728 entries, 0 to 727
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country_name                  728 non-null    object
#  1   Happiness_Rank                728 non-null    int64
#  2   Happiness_score               728 non-null    float64
#  3   Upperwhisker                  728 non-null    float64
#  4   Lowerwhisker                  728 non-null    float64
#  5   Economy_(GDP_per_Capita)	     728 non-null    float64
#  6   Social_support                728 non-null    float64
#  7   Healthy_life_expectancy       728 non-null    float64
#  8   Freedom_to_make_life_choices  728 non-null    float64
#  9   Generosity                    728 non-null    float64
#  10  Perceptions_of_corruption     728 non-null    float64
#  11  Year                          728 non-null    int64
# dtypes: float64(9), int64(2), object(1)
# memory usage: 68.4+ KB
# None
#        Happiness_Rank  Happiness_score  Upperwhisker  Lowerwhisker  \
# count      728.000000       728.000000    728.000000    728.000000
# mean        73.401099         5.524740      5.640658      5.408864
# std         42.232618         1.113797      1.095239      1.133577
# min          1.000000         1.721000      1.775000      1.667000
# 25%         37.000000         4.770000      4.905000      4.648500
# 50%         73.000000         5.583000      5.689500      5.482000
# 75%        110.000000         6.325500      6.430750      6.214250
# max        153.000000         7.842000      7.904000      7.780000
#
#        Economy_(GDP_per_Capita)\t  Social_support  Healthy_life_expectancy  \
# count                  728.000000      728.000000               728.000000
# mean                     1.200348        1.026796                 0.541228
# std                      0.473101        0.332633                 0.223314
# min                      0.000000        0.000000                 0.000000
# 25%                      0.881500        0.813250                 0.380750
# 50%                      1.239500        1.067000                 0.555000
# 75%                      1.535250        1.283750                 0.702250
# max                      2.209000        1.620000                 1.140000
#
#        Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption  \
# count                    728.000000  728.000000                 728.000000
# mean                       0.526359    0.162572                   0.143833
# std                        0.155722    0.088761                   0.121360
# min                        0.000000    0.000000                   0.000000
# 25%                        0.430000    0.099000                   0.060000
# 50%                        0.546500    0.149000                   0.110500
# 75%                        0.638250    0.214250                   0.180000
# max                        0.863000    0.570000                   0.587000
#
#               Year
# count   728.000000
# mean   2021.956044
# std       1.421293
# min    2020.000000
# 25%    2021.000000
# 50%    2022.000000
# 75%    2023.000000
# max    2024.000000

# %%
# Eksik değerleri say
print(df.isnull().sum())

# Eksik değerleri görselleştirme
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
sns.heatmap(df.isnull(), cmap="viridis", cbar=False, yticklabels=False)
plt.show()
# Out:
# Country_name                    0
# Happiness_Rank                  0
# Happiness_score                 0
# Upperwhisker                    0
# Lowerwhisker                    0
# Economy_(GDP_per_Capita)\t      0
# Social_support                  0
# Healthy_life_expectancy         0
# Freedom_to_make_life_choices    0
# Generosity                      0
# Perceptions_of_corruption       0
# Year                            0
# dtype: int64
# c:\Users\balla\OneDrive\Documents\CapStoneProject_2025\.venv\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.draw()
# c:\Users\balla\OneDrive\Documents\CapStoneProject_2025\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df["Happiness_score"].hist(bins=30)
plt.show()

# %%
# choose numeric columns
numeric_df = df.select_dtypes(include=["number"])

# correlation matrix
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.show()
# Out:
# c:\Users\balla\OneDrive\Documents\CapStoneProject_2025\.venv\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.draw()
# c:\Users\balla\OneDrive\Documents\CapStoneProject_2025\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# top 10 most frequent countries
top_countries = df["Country_name"].value_counts().nlargest(10)

# barplot
plt.figure(figsize=(10, 8))
sns.barplot(y=top_countries.index, x=top_countries.values, palette="coolwarm")
plt.xlabel("Count")
plt.ylabel("Country Name")
plt.title("Top 10 Most Frequent Countries in Dataset")
plt.show()
# Out:
# C:\Users\balla\AppData\Local\Temp\ipykernel_10776\1952214918.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_countries.index, x=top_countries.values, palette="coolwarm")

# %% [markdown]
# ## Objectives
#
# * Write your notebook objective here, for example, "Fetch data from Kaggle and save as raw data", or "engineer features for modelling"
#
# ## Inputs
#
# * Write down which data or information you need to run the notebook
#
# ## Outputs
#
# * Write here which files, code or artefacts you generate by the end of the notebook
#
# ## Additional Comments
#
# * If you have any additional comments that don't fit in the previous bullets, please state them here.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\balla\\OneDrive\\Documents\\CapStoneProject_2025\\jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\balla\\OneDrive\\Documents\\CapStoneProject_2025'

# %% [markdown]
# # Section 1

# %% [markdown]
# Section 1 content

# %% [markdown]
# ---

# %% [markdown]
# # Section 2

# %% [markdown]
# Section 2 content

# %% [markdown]
# ---
